# %% [markdown]
# <a href="https://colab.research.google.com/github/sejalkate/Global-Tech-Intern/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# Load the dataset

# %%
dataset = pd.read_csv('diabetes.csv')

# %% [markdown]
# Display the first few rows of the dataset

# %%
print("Original Dataset:")
print(dataset.head())
# Out:
# Original Dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Display all rows of the dataset

# %%
dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Handling missing values
# Replace missing values with the mean of each column

# %%
dataset.fillna(dataset.mean(), inplace=True)

# %% [markdown]
# Drop unnecessary column
# Drop 'Age' and 'BMI' columns

# %%
dataset.drop(['Age', 'BMI'], axis=1, inplace=True)

# %% [markdown]
# Split the dataset into features (X) and target variable (y)

# %%
X = dataset.drop('Outcome', axis=1)
Y = dataset['Outcome']

# %% [markdown]
# Split the dataset into training and testing sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# Standardize features by removing the mean and scaling to unit variance

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Display the processed dataset

# %%
print("\nProcessed Dataset:")
print(X_train.head())
# Out:
# Processed Dataset:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 60             2       84              0              0        0
# 618            9      112             82             24        0
# 346            1      139             46             19       83
# 294            0      161             50              0        0
# 231            6      134             80             37      370
#
#      DiabetesPedigreeFunction
# 60                      0.304
# 618                     1.282
# 346                     0.654
# 294                     0.254
# 231                     0.238

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 60             2       84              0              0        0
# 618            9      112             82             24        0
# 346            1      139             46             19       83
# 294            0      161             50              0        0
# 231            6      134             80             37      370
# ..           ...      ...            ...            ...      ...
# 71             5      139             64             35      140
# 106            1       96            122              0        0
# 270           10      101             86             37        0
# 435            0      141              0              0        0
# 102            0      125             96              0        0
#
#      DiabetesPedigreeFunction
# 60                      0.304
# 618                     1.282
# 346                     0.654
# 294                     0.254
# ...

# %%
Y_train.head()
# Out:
# 60     0
# 618    1
# 346    0
# 294    0
# 231    1
# Name: Outcome, dtype: int64
